# %% [markdown]
# <a href="https://colab.research.google.com/github/unbelief/mlp-mixer-cifar100/blob/main/mlp_mixer_cifar100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/unbelief/mlp-mixer-cifar100.git
# Out:
# Cloning into 'mlp-mixer-cifar100'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 46 (delta 14), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 11.49 KiB | 11.49 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# %cd /content/mlp-mixer-cifar100
# Out:
# /content/mlp-mixer-cifar100

# %%
# !python smoke_test.py
# Out:
# tiny: output=(2, 100), params=164,548
# small: output=(2, 100), params=351,460
# base: output=(2, 100), params=1,021,348
# Smoke test passed.

# %%
# !python train.py --model small --epochs 30 --batch-size 64
# Out:
# Device: cuda
# Model: small
# Trainable parameters: 351,460
# 100% 169M/169M [02:48<00:00, 1.00MB/s]
# Epoch 01/30 | train loss 4.0914 acc 9.55% | val loss 3.7350 acc 17.04%
# Epoch 02/30 | train loss 3.6506 acc 18.10% | val loss 3.4505 acc 22.16%
# Epoch 03/30 | train loss 3.4053 acc 23.18% | val loss 3.2860 acc 25.96%
# Epoch 04/30 | train loss 3.2533 acc 26.46% | val loss 3.1269 acc 30.12%
# Epoch 05/30 | train loss 3.1328 acc 29.55% | val loss 3.0340 acc 32.18%
# Epoch 06/30 | train loss 3.0317 acc 31.98% | val loss 2.9709 acc 33.80%
# Epoch 07/30 | train loss 2.9383 acc 34.40% | val loss 2.8783 acc 36.96%
# Epoch 08/30 | train loss 2.8651 acc 36.09% | val loss 2.7982 acc 39.02%
# Epoch 09/30 | train loss 2.8013 acc 37.67% | val loss 2.7575 acc 40.18%
# Epoch 10/30 | train loss 2.7435 acc 39.65% | val loss 2.7565 acc 39.90%
# Epoch 11/30 | train loss 2.6956 acc 40.59% | val loss 2.6998 acc 41.58%
# Epoch 12/30 | train loss 2.6446 acc 41.86% | val loss 2.6802 acc 41.78%
# ...

# %%
# !python train.py --model small --epochs 50 --batch-size 64
# Out:
# Device: cuda
# Model: small
# Trainable parameters: 351,460
# Epoch 01/50 | train loss 4.0914 acc 9.55% | val loss 3.7350 acc 17.04%
# Epoch 02/50 | train loss 3.6505 acc 18.11% | val loss 3.4503 acc 22.16%
# Epoch 03/50 | train loss 3.4053 acc 23.19% | val loss 3.2855 acc 25.98%
# Epoch 04/50 | train loss 3.2533 acc 26.42% | val loss 3.1266 acc 30.06%
# Epoch 05/50 | train loss 3.1326 acc 29.54% | val loss 3.0318 acc 32.22%
# Epoch 06/50 | train loss 3.0313 acc 31.97% | val loss 2.9700 acc 33.74%
# Epoch 07/50 | train loss 2.9376 acc 34.40% | val loss 2.8770 acc 36.78%
# Epoch 08/50 | train loss 2.8646 acc 36.13% | val loss 2.7949 acc 39.12%
# Epoch 09/50 | train loss 2.8015 acc 37.66% | val loss 2.7534 acc 40.36%
# Epoch 10/50 | train loss 2.7434 acc 39.58% | val loss 2.7585 acc 39.54%
# Epoch 11/50 | train loss 2.6961 acc 40.56% | val loss 2.7006 acc 41.60%
# Epoch 12/50 | train loss 2.6443 acc 41.86% | val loss 2.6817 acc 41.38%
# ...

# %%
# !python evaluate.py
# Out:
# Test loss: 1.8455
# Test accuracy: 52.27%
#                precision    recall  f1-score   support
#
#         apple     0.6842    0.7800    0.7290       100
# aquarium_fish     0.5962    0.6200    0.6078       100
#          baby     0.3964    0.4400    0.4171       100
#          bear     0.3846    0.2500    0.3030       100
#        beaver     0.3875    0.3100    0.3444       100
#           bed     0.4255    0.4000    0.4124       100
#           bee     0.5520    0.6900    0.6133       100
#        beetle     0.5304    0.6100    0.5674       100
#       bicycle     0.6000    0.6600    0.6286       100
#        bottle     0.6986    0.5100    0.5896       100
#          bowl     0.2895    0.3300    0.3084       100
#           boy     0.4412    0.3000    0.3571       100
#        bridge     0.5686    0.5800    0.5743       100
#           bus     0.4737    0.3600    0.4091       100
#     butterfly     0.3661    0.4100    0.3868       100
# ...

# %%
# !mkdir -p results/small

# %%
# !mkdir -p checkpoints/small

# %%
# !cp results/training_summary.json results/small/
# !cp results/training_curves.png results/small/
# !cp results/training_curves_accuracy.png results/small/

# !cp checkpoints/best.pt checkpoints/small/
# !cp checkpoints/last.pt checkpoints/small/

# %%
# !python train.py --model base --epochs 50 --batch-size 64
# Out:
# Device: cuda
# Model: base
# Trainable parameters: 1,021,348
# 100% 169M/169M [14:30<00:00, 194kB/s]
# Epoch 01/50 | train loss 4.0083 acc 10.73% | val loss 3.6507 acc 17.88%
# Epoch 02/50 | train loss 3.4959 acc 20.96% | val loss 3.2888 acc 25.76%
# Epoch 03/50 | train loss 3.2334 acc 26.80% | val loss 3.0583 acc 31.12%
# Epoch 04/50 | train loss 3.0482 acc 31.54% | val loss 2.9327 acc 34.82%
# Epoch 05/50 | train loss 2.9014 acc 35.27% | val loss 2.8161 acc 37.42%
# Epoch 06/50 | train loss 2.7799 acc 38.57% | val loss 2.7591 acc 39.42%
# Epoch 07/50 | train loss 2.6712 acc 41.14% | val loss 2.6874 acc 40.74%
# Epoch 08/50 | train loss 2.5840 acc 43.56% | val loss 2.5922 acc 44.04%
# Epoch 09/50 | train loss 2.5030 acc 45.95% | val loss 2.5527 acc 45.28%
# Epoch 10/50 | train loss 2.4251 acc 47.60% | val loss 2.5217 acc 46.04%
# Epoch 11/50 | train loss 2.3497 acc 50.16% | val loss 2.4937 acc 47.36%
# Epoch 12/50 | train loss 2.2874 acc 52.05% | val loss 2.4542 acc 47.72%
# ...

# %%
# !python evaluate.py
# Out:
# Test loss: 1.9998
# Test accuracy: 53.29%
#                precision    recall  f1-score   support
#
#         apple     0.7207    0.8000    0.7583       100
# aquarium_fish     0.6569    0.6700    0.6634       100
#          baby     0.4330    0.4200    0.4264       100
#          bear     0.3214    0.2700    0.2935       100
#        beaver     0.3939    0.3900    0.3920       100
#           bed     0.4684    0.3700    0.4134       100
#           bee     0.5463    0.5900    0.5673       100
#        beetle     0.4846    0.6300    0.5478       100
#       bicycle     0.6484    0.5900    0.6178       100
#        bottle     0.6136    0.5400    0.5745       100
#          bowl     0.2551    0.2500    0.2525       100
#           boy     0.3645    0.3900    0.3768       100
#        bridge     0.6019    0.6500    0.6250       100
#           bus     0.4600    0.4600    0.4600       100
#     butterfly     0.5588    0.3800    0.4524       100
# ...
